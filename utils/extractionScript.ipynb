# %%
import gzip
import shutil

with gzip.open('./meta_Electronics.jsonl.gz', 'rb') as f_in:
    with open('./meta_Electronics.jsonl', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %%
import gzip
import shutil

with gzip.open('./Electronics.jsonl.gz', 'rb') as f_in:
    with open('./Electronics.jsonl', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
