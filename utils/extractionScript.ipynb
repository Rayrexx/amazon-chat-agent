# %%
import gzip
import shutil

with gzip.open('../data/meta_Electronics.jsonl.gz', 'rb') as f_in:
    with open('../data/meta_Electronics.jsonl', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)

# %%
with gzip.open('../data/Electronics.jsonl.gz', 'rb') as f_in:
    with open('../data/Electronics.jsonl', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
